# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.head(15)
# Out:
#    show_id     type  title              director  \
# 0       s1  TV Show     3%                   NaN
# 1       s2    Movie   7:19     Jorge Michel Grau
# 2       s3    Movie  23:59          Gilbert Chan
# 3       s4    Movie      9           Shane Acker
# 4       s5    Movie     21        Robert Luketic
# 5       s6  TV Show     46           Serdar Akar
# 6       s7    Movie    122       Yasir Al Yasiri
# 7       s8    Movie    187        Kevin Reynolds
# 8       s9    Movie    706         Shravan Kumar
# 9      s10    Movie   1920          Vikram Bhatt
# 10     s11    Movie   1922          Zak Hilditch
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
# 13     s14    Movie  2,215   Nottapon Boonprakob
# 14     s15    Movie   3022            John Suits
#
#                                                  cast                country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# ...

# %%
df['date_added']=pd.to_datetime(df.date_added)

# %%
df['day_of_the_week_date_added'] = df.date_added.dt.day_name()

#adds a new column which represents the added date weekday name

# %%
cols = list(df.columns)
new_cols = (cols[0:7])
new_cols.append(cols[-1])
new_cols.extend(cols[7:12])

# reordering columns

# %%
df = df[new_cols]
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#   day_of_the_week_date_added  release_year rating   duration  \
# 0                     Friday          2020  TV-MA  4 Seasons
# 1                     Friday          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
