# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("survey_results_public.csv", low_memory=False)

# %%
df.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %%
df.drop(columns=['AssessJob1', 'AssessJob2', 'AssessJob3', 'AssessJob4', 'AssessJob5', 'AssessJob6', 'AssessJob7', 'AssessJob8', 'AssessJob9', 'AssessJob10'], inplace=True)
df.drop(columns=['JobEmailPriorities1', 'JobEmailPriorities2', 'JobEmailPriorities3', 'JobEmailPriorities4', 'JobEmailPriorities5', 'JobEmailPriorities6', 'JobEmailPriorities7'], inplace=True)
df.drop(columns=['AssessBenefits1', 'AssessBenefits2', 'AssessBenefits3', 'AssessBenefits4', 'AssessBenefits5', 'AssessBenefits6', 'AssessBenefits7', 'AssessBenefits8', 'AssessBenefits9', 'AssessBenefits10', 'AssessBenefits11'], inplace=True)
df.drop(columns=['JobContactPriorities1', 'JobContactPriorities2', 'JobContactPriorities3', 'JobContactPriorities4', 'JobContactPriorities5'], inplace=True)
df.drop(columns=['AdsPriorities1', 'AdsPriorities2', 'AdsPriorities3', 'AdsPriorities4', 'AdsPriorities5','AdsPriorities6', 'AdsPriorities7'], inplace=True)

# %%
#df['FormalEducation'] =df['FormalEducation'].astype('category').cat.codes
#df['UndergradMajor'] =df['UndergradMajor'].astype('category').cat.codes
#df['CompanySize'] =df['CompanySize'].astype('category').cat.codes
#df['JobSatisfaction'] =df['JobSatisfaction'].astype('category').cat.codes
#df['CareerSatisfaction'] =df['CareerSatisfaction'].astype('category').cat.codes
#df['YearsCoding'] =df['YearsCoding'].astype('category').cat.codes
#df['YearsCodingProf'] =df['YearsCodingProf'].astype('category').cat.codes
#df['LastNewJob'] =df['LastNewJob'].astype('category').cat.codes
#df['SalaryType'] =df['SalaryType'].astype('category').cat.codes
df['Age'] =df['Age'].astype('category').cat.codes
df['Gender'] =df['Gender'].astype('category').cat.codes

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Job Satisfaction is more correlated with Career satisfation, Last New Job and Years Coding as Professional

# %%
# Salary is more correlated with Years Coding as Professional and Age
